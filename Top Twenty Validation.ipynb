# %%
import pandas as pd

import matplotlib.pyplot as plt

# %%
validation_data = pd.read_csv('output_padded_top_twenty/validation_measures_64.csv')

# %%
plt.plot(validation_data['acc'], ':')
plt.plot(validation_data['val_acc']);

# %%
plt.plot(validation_data['loss'], ':')
plt.plot(validation_data['val_loss']);

# %%
validation_data = pd.read_csv('output_padded_top_twenty_without_bidi/validation_measures_128.csv')

# %%
plt.plot(validation_data['acc'], ':')
plt.plot(validation_data['val_acc']);

# %%
plt.plot(validation_data['loss'], ':')
plt.plot(validation_data['val_loss']);
