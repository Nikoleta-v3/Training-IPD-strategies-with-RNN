# %%
import pandas as pd

# %%
df = pd.read_csv('hawk_output/output/validation_measures_run_200_1_1.csv')

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    Unnamed: 0       acc   val_acc      loss  val_loss
# 0           0  0.788698  0.792098  0.514347  0.546580
# 1           1  0.793094  0.788406  0.499294  0.531841
# 2           2  0.794557  0.794413  0.496547  0.528685
# 3           3  0.794955  0.791008  0.495137  0.559501
# 4           4  0.793526  0.794314  0.497192  0.523818

# %%
plt.plot(df['acc'], '--', label='acc');
plt.plot(df['val_acc'], ':', label='val_acc');

# %%
plt.plot(df['loss'], '--', label='loss');
plt.plot(df['val_loss'], ':', label='val_loss');
