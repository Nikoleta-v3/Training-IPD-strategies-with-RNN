# %%
import pandas as pd

# %%
df = pd.read_csv('output/validation_measures_200_10_1000.csv')

# %%
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    Unnamed: 0       acc   val_acc      loss  val_loss
# 0           0  0.659165  0.672937  0.640752  0.631031
# 1           1  0.664269  0.674591  0.642905  0.630370
# 2           2  0.662789  0.672696  0.644506  0.633216
# 3           3  0.666284  0.678773  0.638193  0.626122
# 4           4  0.668911  0.678507  0.635613  0.626603

# %%
plt.plot(df['acc'], '--', label='acc');
plt.plot(df['val_acc'], ':', label='val_acc');

plt.legend();

# %%
plt.plot(df['loss'], '--', label='loss');
plt.plot(df['val_loss'], ':', label='val_loss');
