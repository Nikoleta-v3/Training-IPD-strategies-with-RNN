# %%
import pandas as pd

import glob

import matplotlib.pyplot as plt

# %%
def read_validation_dataframes(files_location):
    filenames = glob.glob(files_location)
    dfs = []
    for file in filenames:
        df = pd.read_csv(file, index_col=0)
        dfs.append(df)
    df = pd.concat(dfs).reset_index()
    return df

# %%
files_location = "hawk_output/output_lstm/validation_measures_run_*.csv"
df = read_validation_dataframes(files_location)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 4))

ax[0].plot(df['acc'], '--', label='acc');
ax[0].plot(df['val_acc'], ':', label='val_acc');


ax[1].plot(df['loss'], '--', label='loss');
ax[1].plot(df['val_loss'], ':', label='val_loss');

for i in range(2):
    ax[i].legend();

# %% [markdown]
# **Padded**

# %%
files_location = "hawk_output/output_padded/validation_measures_*.csv"
df = read_validation_dataframes(files_location)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 4))

ax[0].plot(df['acc'], '--', label='acc');
ax[0].plot(df['val_acc'], ':', label='val_acc');


ax[1].plot(df['loss'], '--', label='loss');
ax[1].plot(df['val_loss'], ':', label='val_loss');

for i in range(2):
    ax[i].legend();

# %% [markdown]
# **Unknown lenght classification**

# %%
files_location = "hawk_output/output_lstm_unknown_lenght/validation_measures_run_100_*.csv"
df = read_validation_dataframes(files_location)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 4))

ax[0].plot(df['acc'], '--', label='acc');
ax[0].plot(df['val_acc'], ':', label='val_acc');


ax[1].plot(df['loss'], '--', label='loss');
ax[1].plot(df['val_loss'], ':', label='val_loss');

for i in range(2):
    ax[i].legend();

# %% [markdown]
# **Top twenty strategies**

# %%
files_location = "hawk_output/output_lstm_top_twenty/validation_measures_run_*.csv"
df = read_validation_dataframes(files_location)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 4))

ax[0].plot(df['acc'], '--', label='acc');
ax[0].plot(df['val_acc'], ':', label='val_acc');


ax[1].plot(df['loss'], '--', label='loss');
ax[1].plot(df['val_loss'], ':', label='val_loss');

for i in range(2):
    ax[i].legend();

# %%
files_location = "hawk_output/output_lstm_unknown_lenght/validation_measures_run_*.csv"
df = read_validation_dataframes(files_location)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 4))

ax[0].plot(df['acc'], '--', label='acc');
ax[0].plot(df['val_acc'], ':', label='val_acc');


ax[1].plot(df['loss'], '--', label='loss');
ax[1].plot(df['val_loss'], ':', label='val_loss');

for i in range(2):
    ax[i].legend();

# %%
files_location = "hawk_output/output_padded_top_twenty_without_bidi/validation_measures_128.csv"
df = read_validation_dataframes(files_location)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 4))

ax[0].plot(df['acc'], '--', label='acc');
ax[0].plot(df['val_acc'], ':', label='val_acc');


ax[1].plot(df['loss'], '--', label='loss');
ax[1].plot(df['val_loss'], ':', label='val_loss');

for i in range(2):
    ax[i].legend();

# %%
files_location = "hawk_output/output_padded_top_twenty/validation_measures_64.csv"
df = read_validation_dataframes(files_location)

# %%
fig, ax = plt.subplots(ncols=2, figsize=(9, 4))

ax[0].plot(df['acc'], '--', label='acc');
ax[0].plot(df['val_acc'], ':', label='val_acc');


ax[1].plot(df['loss'], '--', label='loss');
ax[1].plot(df['val_loss'], ':', label='val_loss');

for i in range(2):
    ax[i].legend();
